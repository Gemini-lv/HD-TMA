# %%
pip install Hough-TMF
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 打包
# !python setup.py sdist bdist_wheel
# Out:
# running sdist
# running egg_info
# writing Hough_TMF.egg-info\PKG-INFO
# writing dependency_links to Hough_TMF.egg-info\dependency_links.txt
# writing top-level names to Hough_TMF.egg-info\top_level.txt
# reading manifest file 'Hough_TMF.egg-info\SOURCES.txt'
# adding license file 'LICENCE'
# writing manifest file 'Hough_TMF.egg-info\SOURCES.txt'
# running check
# creating Hough-TMF-0.1.1
# creating Hough-TMF-0.1.1\Hough_TMF.egg-info
# creating Hough-TMF-0.1.1\hd_tmf
# copying files to Hough-TMF-0.1.1...
# copying LICENCE -> Hough-TMF-0.1.1
# copying README.md -> Hough-TMF-0.1.1
# copying setup.py -> Hough-TMF-0.1.1
# copying Hough_TMF.egg-info\PKG-INFO -> Hough-TMF-0.1.1\Hough_TMF.egg-info
# copying Hough_TMF.egg-info\SOURCES.txt -> Hough-TMF-0.1.1\Hough_TMF.egg-info
# copying Hough_TMF.egg-info\dependency_links.txt -> Hough-TMF-0.1.1\Hough_TMF.egg-info
# copying Hough_TMF.egg-info\top_level.txt -> Hough-TMF-0.1.1\Hough_TMF.egg-info
# ...

# %%
#
